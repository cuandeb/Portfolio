# %%
import extraction_utils as extract
import curvefit_utils as fit
import efficiency as eff
import calibration_resolution as calib


if __name__ == "__main__":
    calib.comparison_res_curve()
    eff.off_ax_comparison()
    eff.combine()
# Out:
# C:\Users\cuand\Gamma Ray Laboratory\Gamma Detectors\calibration_resolution.py:394: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(result)
# C:\Users\cuand\Gamma Ray Laboratory\Gamma Detectors\calibration_resolution.py:394: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(result)
# [(59.5412, 95.0864890827507), (302.8508, 62.12038913105637), (356.0129, 78.46425049937262), (1173.228, 32.20246837364104), (1332.501, 31.03363430092306), (661.657, 55.112804033520206), (81.0, 96.94947830960587)]
# [(59.5412, 59.78900090816029), (276.4, 39.71858288303447), (302.8508, 34.261135471509554), (356.02, 29.03619076689618), (383.8, 26.52891175667336), (1173.228, 10.563031003364209), (1332.501, 9.087845823658341), (661.657, 16.59492837248826), (81.0, 67.94140740400307)]
# [(59.5412, 68.11588117541076), (302.8508, 41.99254957776825), (356.0129, 42.24261926198008), (302.8508, 46.88339051704081), (356.0129, 42.55533806562295), (661.657, 17.64976585504493), (81.0, 90.81393602703153)]
# [(26.3446, 27.759913156700463), (59.5412, 23.3762235878985), (81.0, 19.732737691197485)]
